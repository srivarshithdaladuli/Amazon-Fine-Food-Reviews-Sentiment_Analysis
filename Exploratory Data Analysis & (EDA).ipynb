# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns 
import warnings
warnings.filterwarnings('ignore')
import os

# %%
ml = pd.read_csv(r"F:\Srivarshith Daladuli\Project\amazon_food_reviews.csv")

# %%
ml
# Out:
#         Unnamed: 0                        0                         1  \
# 0                0  ProductId: B001E4KFG0\n  UserId: A3SGXH7AUHU8GW\n
# 1                1  ProductId: B00813GRG4\n  UserId: A1D87F6ZCVE5NK\n
# 2                2  ProductId: B000LQOCH0\n   UserId: ABXLMWJIXXAIN\n
# 3                3  ProductId: B000UA0QIQ\n  UserId: A395BORC6FGVXV\n
# 4                4  ProductId: B006K2ZZ7K\n  UserId: A1UQRSCLF8GW1T\n
# ...            ...                      ...                       ...
# 568448      568448  ProductId: B001EO7N10\n  UserId: A1F6BHEYB7R6R7\n
# 568449      568449  ProductId: B001EO7N10\n  UserId: A28KG5XORO54AY\n
# 568450      568450  ProductId: B003S1WTCU\n  UserId: A3I8AFVPEE8KI5\n
# 568451      568451  ProductId: B004I613EE\n  UserId: A121AA1GQV751Z\n
# 568452      568452  ProductId: B004I613EE\n   UserId: A3IBEVCTXKNOH\n
#
#                                                      2  \
# 0                            ProfileName: delmartian\n
# ...

# %%
ml.shape
# Out:
# (568453, 10)

# %%
ml.describe()
# Out:
#           Unnamed: 0
# count  568453.000000
# mean   284226.000000
# std    164098.390623
# min         0.000000
# 25%    142113.000000
# 50%    284226.000000
# 75%    426339.000000
# max    568452.000000

# %%
['ProductId','UserId','ProfileName','HelpfulnessNumerator','HelpfulnessDenominator','Score','Time','ReviewSummary','ReviewText']
# Out:
# ['ProductId',
#  'UserId',
#  'ProfileName',
#  'HelpfulnessNumerator',
#  'HelpfulnessDenominator',
#  'Score',
#  'Time',
#  'ReviewSummary',
#  'ReviewText']

# %%
ml.head()
# Out:
#    Unnamed: 0                        0                         1  \
# 0           0  ProductId: B001E4KFG0\n  UserId: A3SGXH7AUHU8GW\n
# 1           1  ProductId: B00813GRG4\n  UserId: A1D87F6ZCVE5NK\n
# 2           2  ProductId: B000LQOCH0\n   UserId: ABXLMWJIXXAIN\n
# 3           3  ProductId: B000UA0QIQ\n  UserId: A395BORC6FGVXV\n
# 4           4  ProductId: B006K2ZZ7K\n  UserId: A1UQRSCLF8GW1T\n
#
#                                                 2                          3  \
# 0                       ProfileName: delmartian\n  HelpfulnessNumerator: 1\n
# 1                           ProfileName: dll pa\n  HelpfulnessNumerator: 0\n
# 2  ProfileName: Natalia Corres "Natalia Corres"\n  HelpfulnessNumerator: 1\n
# 3                             ProfileName: Karl\n  HelpfulnessNumerator: 3\n
# 4    ProfileName: Michael D. Bigham "M. Wassir"\n  HelpfulnessNumerator: 0\n
#
#                              4           5                   6  \
# ...

# %%
ml.drop('Unnamed: 0',axis=1,inplace=True)

# %%
ml
# Out:
#                               0                         1  \
# 0       ProductId: B001E4KFG0\n  UserId: A3SGXH7AUHU8GW\n
# 1       ProductId: B00813GRG4\n  UserId: A1D87F6ZCVE5NK\n
# 2       ProductId: B000LQOCH0\n   UserId: ABXLMWJIXXAIN\n
# 3       ProductId: B000UA0QIQ\n  UserId: A395BORC6FGVXV\n
# 4       ProductId: B006K2ZZ7K\n  UserId: A1UQRSCLF8GW1T\n
# ...                         ...                       ...
# 568448  ProductId: B001EO7N10\n  UserId: A1F6BHEYB7R6R7\n
# 568449  ProductId: B001EO7N10\n  UserId: A28KG5XORO54AY\n
# 568450  ProductId: B003S1WTCU\n  UserId: A3I8AFVPEE8KI5\n
# 568451  ProductId: B004I613EE\n  UserId: A121AA1GQV751Z\n
# 568452  ProductId: B004I613EE\n   UserId: A3IBEVCTXKNOH\n
#
#                                                      2  \
# 0                            ProfileName: delmartian\n
# 1                                ProfileName: dll pa\n
# 2       ProfileName: Natalia Corres "Natalia Corres"\n
# ...

# %%
ml.rename(columns={'0':'ProductId','1':'UserId','2':'ProfileName','3':'HelpfulnessNumerator','4':'HelpfulnessDenominator','5':'Score','6':'Time','7':'ReviewSummary','8':'ReviewText'},inplace=True)

# %%
ml
# Out:
#                       ProductId                    UserId  \
# 0       ProductId: B001E4KFG0\n  UserId: A3SGXH7AUHU8GW\n
# 1       ProductId: B00813GRG4\n  UserId: A1D87F6ZCVE5NK\n
# 2       ProductId: B000LQOCH0\n   UserId: ABXLMWJIXXAIN\n
# 3       ProductId: B000UA0QIQ\n  UserId: A395BORC6FGVXV\n
# 4       ProductId: B006K2ZZ7K\n  UserId: A1UQRSCLF8GW1T\n
# ...                         ...                       ...
# 568448  ProductId: B001EO7N10\n  UserId: A1F6BHEYB7R6R7\n
# 568449  ProductId: B001EO7N10\n  UserId: A28KG5XORO54AY\n
# 568450  ProductId: B003S1WTCU\n  UserId: A3I8AFVPEE8KI5\n
# 568451  ProductId: B004I613EE\n  UserId: A121AA1GQV751Z\n
# 568452  ProductId: B004I613EE\n   UserId: A3IBEVCTXKNOH\n
#
#                                            ProfileName  \
# 0                            ProfileName: delmartian\n
# 1                                ProfileName: dll pa\n
# 2       ProfileName: Natalia Corres "Natalia Corres"\n
# ...

# %%
ml.columns
# Out:
# Index(['ProductId', 'UserId', 'ProfileName', 'HelpfulnessNumerator',
#        'HelpfulnessDenominator', 'Score', 'Time', 'ReviewSummary',
#        'ReviewText'],
#       dtype='object')

# %%
ml['ProductId'] = ml['ProductId'].apply(lambda x:x.replace('ProductId:',""))
ml['ProductId'] = ml['ProductId'].apply(lambda x:x.replace('\n',""))
ml['ProductId'] = ml['ProductId'].apply(lambda x:x.replace(':',""))
ml['ProfileName'] = ml['ProfileName'].apply(lambda x:x.replace(':',""))
ml['HelpfulnessNumerator'] = ml['HelpfulnessNumerator'].apply(lambda x:x.replace('HelpfulnessNumerator:',""))
ml['HelpfulnessDenominator'] = ml['HelpfulnessDenominator'].apply(lambda x:x.replace('HelpfulnessDenominator:',""))
ml['Score'] = ml['Score'].apply(lambda x:x.replace('Score:',""))
ml['Time'] = ml['Time'].apply(lambda x:x.replace('Time:',""))
ml['ReviewSummary'] = ml['ReviewSummary'].apply(lambda x:x.replace('ReviewSummary:',""))
ml['ReviewText'] = ml['ReviewText'].apply(lambda x:x.replace('ReviewText:',""))
ml['ProfileName'] = ml['ProfileName'].apply(lambda x:x.replace('\n',""))
ml['HelpfulnessNumerator'] = ml['HelpfulnessNumerator'].apply(lambda x:x.replace('\n',""))
ml['HelpfulnessDenominator'] = ml['HelpfulnessDenominator'].apply(lambda x:x.replace('\n',""))
ml['Score'] = ml['Score'].apply(lambda x:x.replace('\n',""))
ml['Time'] = ml['Time'].apply(lambda x:x.replace('\n',""))
ml['ReviewSummary'] = ml['ReviewSummary'].apply(lambda x:x.replace('\n',""))
ml['UserId'] = ml['UserId'].apply(lambda x:x.replace('\n',""))
ml['UserId'] = ml['UserId'].apply(lambda x:x.replace('UserId:',""))
ml['ProfileName'] = ml['ProfileName'].apply(lambda x:x.replace('ProfileName',""))
ml['UserId'] = ml['UserId'].apply(lambda x:x.replace(':',""))

# %%
ml.head()
# Out:
#      ProductId           UserId                       ProfileName  \
# 0   B001E4KFG0   A3SGXH7AUHU8GW                        delmartian
# 1   B00813GRG4   A1D87F6ZCVE5NK                            dll pa
# 2   B000LQOCH0    ABXLMWJIXXAIN   Natalia Corres "Natalia Corres"
# 3   B000UA0QIQ   A395BORC6FGVXV                              Karl
# 4   B006K2ZZ7K   A1UQRSCLF8GW1T     Michael D. Bigham "M. Wassir"
#
#   HelpfulnessNumerator HelpfulnessDenominator Score         Time  \
# 0                    1                      1     5   1303862400
# 1                    0                      0     1   1346976000
# 2                    1                      1     4   1219017600
# 3                    3                      3     2   1307923200
# 4                    0                      0     5   1350777600
#
#             ReviewSummary                                         ReviewText
# 0   Good Quality Dog Food   I have bought several of the Vitality canned ...
# ...

# %%
ml.shape
# Out:
# (568453, 9)

# %%
ml.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 568453 entries, 0 to 568452
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   ProductId               568453 non-null  object
#  1   UserId                  568453 non-null  object
#  2   ProfileName             568453 non-null  object
#  3   HelpfulnessNumerator    568453 non-null  object
#  4   HelpfulnessDenominator  568453 non-null  object
#  5   Score                   568453 non-null  object
#  6   Time                    568453 non-null  object
#  7   ReviewSummary           568453 non-null  object
#  8   ReviewText              568453 non-null  object
# dtypes: object(9)
# memory usage: 39.0+ MB

# %%
ml['HelpfulnessNumerator'] = ml['HelpfulnessNumerator'].astype(str).astype('int64')

# %%
ml['HelpfulnessDenominator'] = ml['HelpfulnessDenominator'].astype(str).astype('int64')

# %%
ml['Score'] = ml['Score'].astype(str).astype('int64')

# %%
amzon_review = ml.drop_duplicates()

# %%
amzon_review.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 568172 entries, 0 to 568452
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   ProductId               568172 non-null  object
#  1   UserId                  568172 non-null  object
#  2   ProfileName             568172 non-null  object
#  3   HelpfulnessNumerator    568172 non-null  int64
#  4   HelpfulnessDenominator  568172 non-null  int64
#  5   Score                   568172 non-null  int64
#  6   Time                    568172 non-null  object
#  7   ReviewSummary           568172 non-null  object
#  8   ReviewText              568172 non-null  object
# dtypes: int64(3), object(6)
# memory usage: 43.3+ MB

# %%
ml['usefulness'] = ml['HelpfulnessNumerator']/ml['HelpfulnessDenominator']

# %%
usefulness = []
for i in ml['usefulness']:
    if i > 0.75:
        usefulness.append(">75%")
    elif i < 0.25:
        usefulness.append("<25%")
    elif i >= 0.25 and i <= 0.75:
        usefulness.append("25-75%")
    else:
        usefulness.append("useless")
ml['usefulness']  = usefulness

# %%
word_count = []
for i in ml['ReviewText']:
    word_count.append(len(i.split()))
ml['word_count'] = word_count

# %%
ml.head()
# Out:
#      ProductId           UserId                       ProfileName  \
# 0   B001E4KFG0   A3SGXH7AUHU8GW                        delmartian
# 1   B00813GRG4   A1D87F6ZCVE5NK                            dll pa
# 2   B000LQOCH0    ABXLMWJIXXAIN   Natalia Corres "Natalia Corres"
# 3   B000UA0QIQ   A395BORC6FGVXV                              Karl
# 4   B006K2ZZ7K   A1UQRSCLF8GW1T     Michael D. Bigham "M. Wassir"
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score         Time  \
# 0                     1                       1      5   1303862400
# 1                     0                       0      1   1346976000
# 2                     1                       1      4   1219017600
# 3                     3                       3      2   1307923200
# 4                     0                       0      5   1350777600
#
#             ReviewSummary                                         ReviewText  \
# 0   Good Quality Dog Food   I have bought several of the Vitality canned ...
# ...

# %% [markdown]
# #### Distribution of Ratings

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='Score',data=amzon_review)
plt.title(' Score(Ratings)')
plt.show()

# %%
sentiment = []
for i in amzon_review['Score']:
    if i > 3:
        sentiment.append('positive')
    elif i < 3:
        sentiment.append('negative')
    else:
        sentiment.append('not')
amzon_review['sentiment'] = sentiment

# %%
amzon_review.head()
# Out:
#      ProductId           UserId                       ProfileName  \
# 0   B001E4KFG0   A3SGXH7AUHU8GW                        delmartian
# 1   B00813GRG4   A1D87F6ZCVE5NK                            dll pa
# 2   B000LQOCH0    ABXLMWJIXXAIN   Natalia Corres "Natalia Corres"
# 3   B000UA0QIQ   A395BORC6FGVXV                              Karl
# 4   B006K2ZZ7K   A1UQRSCLF8GW1T     Michael D. Bigham "M. Wassir"
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score         Time  \
# 0                     1                       1      5   1303862400
# 1                     0                       0      1   1346976000
# 2                     1                       1      4   1219017600
# 3                     3                       3      2   1307923200
# 4                     0                       0      5   1350777600
#
#             ReviewSummary                                         ReviewText  \
# 0   Good Quality Dog Food   I have bought several of the Vitality canned ...
# ...

# %%
pos = amzon_review[amzon_review['sentiment']=='positive']

# %%
pos
# Out:
#           ProductId           UserId                       ProfileName  \
# 0        B001E4KFG0   A3SGXH7AUHU8GW                        delmartian
# 2        B000LQOCH0    ABXLMWJIXXAIN   Natalia Corres "Natalia Corres"
# 4        B006K2ZZ7K   A1UQRSCLF8GW1T     Michael D. Bigham "M. Wassir"
# 5        B006K2ZZ7K    ADT0SRK1MGOEU                    Twoapennything
# 6        B006K2ZZ7K   A1SP2KVKFXXRU1                 David C. Sullivan
# ...             ...              ...                               ...
# 568447   B001EO7N10    APWCOAVILK94B        Real Named Person "wowzee"
# 568448   B001EO7N10   A1F6BHEYB7R6R7                      James Braley
# 568449   B001EO7N10   A28KG5XORO54AY                  Lettie D. Carter
# 568451   B004I613EE   A121AA1GQV751Z                     pksd "pk_007"
# 568452   B004I613EE    A3IBEVCTXKNOH           Kathy A. Welch "katwel"
#
#         HelpfulnessNumerator  HelpfulnessDenominator  Score         Time  \
# ...

# %% [markdown]
# #### Popular words in Positive Reviews (4-5 Rating)

# %%
neg = amzon_review[amzon_review['sentiment']=='negative']
neg
# Out:
#           ProductId           UserId       ProfileName  HelpfulnessNumerator  \
# 1        B00813GRG4   A1D87F6ZCVE5NK            dll pa                     0
# 3        B000UA0QIQ   A395BORC6FGVXV              Karl                     3
# 12       B0009XLVG0    A327PCT23YH90                LT                     1
# 16       B001GVISJM   A3KLWF6WQ5BNYO    Erica Neathery                     0
# 26       B001GVISJM   A3RXAU2N8KV45G            lady21                     0
# ...             ...              ...               ...                   ...
# 568433   B003XUL27E   A1JUG9WCN1A52Z        maudlin666                     0
# 568434   B003XUL27E    ABGQPE97ZVYJ3   Katherine Kelly                     0
# 568435   B003XUL27E   A2PSB4WQHH46HN          carlyowu                     0
# 568446   B001EO7N10   A2P9W8T7NTLG2Z              Andy                     0
# 568450   B003S1WTCU   A3I8AFVPEE8KI5         R. Sawyer                     0
#
# ...

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
import pandas as pd

# %%
comment_words = ''
stopwords = set(STOPWORDS)

for val in pos['ReviewSummary']:
    val = str(val)
    tokens = val.split()
    for i in range(len(tokens)):
        tokens[i] = tokens[i].lower()
    comment_words += " ".join(tokens)+" "
    
wordcloud = WordCloud(width = 600, height = 600,
                background_color ='red',
                stopwords = stopwords,
                min_font_size = 10).generate(comment_words)    
    
plt.figure(figsize = (10, 8), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)
 
plt.show()

# %% [markdown]
# #### Popular words in Negative Reviews (1-2 Rating)

# %%
from PIL import Image

# %%
#mask = np.array(Image.open(r'F:\Srivarshith Daladuli\Project\varshuK.png'))

# %%
comment_words = ''
stopwords = set(STOPWORDS)

for val in neg['ReviewSummary']:
    val = str(val)
    tokens = val.split()
    for i in range(len(tokens)):
        tokens[i] = tokens[i].lower()
    comment_words += " ".join(tokens)+" "
    
wordcloud = WordCloud(width = 600, height = 600,
                #mask = mask,
                background_color ='yellow',
                stopwords = stopwords,
                min_font_size = 10).generate(comment_words)    
    
plt.figure(figsize = (10, 8), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)
 
plt.show()

# %% [markdown]
# #### Distribution of Helpfulness

# %%
plt.figure(figsize=(10,8))
sns.countplot(x='usefulness',data=ml,order=['useless','>75%','25-75%','<25%'],palette="rocket_r")
plt.title('Distribution of Helpfulness')
plt.show()

# %% [markdown]
# #### Rating affect Helpfulness

# %%
ml['usefulness'].value_counts()
# Out:
# useless    270051
# >75%       202836
# 25-75%      57286
# <25%        38280
# Name: usefulness, dtype: int64

# %%
plt.figure(figsize=(10,8))
sns.countplot(x='Score',data=ml,hue='usefulness',hue_order=['>75%','25-75%','<25%'],order=[5,4,3,2,1],palette="rocket_r")
plt.xticks(rotation=90,fontsize=10)
plt.title('COMPARING THE SCORE WITH USEFULNESS')
plt.show()

# %% [markdown]
# #### Word count vary by rating

# %%
rating = ml[ml['Score']== 1].word_count.median()
rating
# Out:
# 62.0

# %%
rating = ml[ml['Score']== 2].word_count.median()
rating
# Out:
# 67.0

# %%
rating = ml[ml['Score']== 3].word_count.median()
rating
# Out:
# 70.0

# %%
rating = ml[ml['Score']== 4].word_count.median()
rating
# Out:
# 65.0

# %%
rating = ml[ml['Score']== 5].word_count.median()
rating
# Out:
# 52.0

# %%
ml.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 568453 entries, 0 to 568452
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   ProductId               568453 non-null  object
#  1   UserId                  568453 non-null  object
#  2   ProfileName             568453 non-null  object
#  3   HelpfulnessNumerator    568453 non-null  int64
#  4   HelpfulnessDenominator  568453 non-null  int64
#  5   Score                   568453 non-null  int64
#  6   Time                    568453 non-null  object
#  7   ReviewSummary           568453 non-null  object
#  8   ReviewText              568453 non-null  object
#  9   usefulness              568453 non-null  object
#  10  word_count              568453 non-null  int64
# dtypes: int64(4), object(7)
# memory usage: 47.7+ MB

# %%
plt.figure(figsize=(10,8))
sns.boxplot(x='Score',y='word_count',data=ml,showfliers=False)
plt.xticks(rotation=90,fontsize=10)
plt.title('COMPARING THE SCORE WITH USEFULNESS')
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.violinplot(x='usefulness',y='word_count',data=ml,order=['>75%','<25%'])
plt.ylim(-50, 400)
plt.xticks(rotation=90,fontsize=10)
plt.title('COMPARING THE SCORE WITH USEFULNESS')
plt.show()
